# %%
import pandas as pd
df = pd.read_csv('data/customers3.csv', index_col='고객ID')
df
# Out:
#       고객명  나이 거주도시        주요관심사  최근1년_방문빈도  평균구매액(만원)  고객만족도(점)  재구매의사(점)
# 고객ID
# C001  박태근  35   시흥  Electronics         75         70        78        92
# C002  이영희  30   안양      fashion         85         92        88        85
# C003  박지성  35   울산          NaN         95        110        91        88
# C004  최민아  40   창원      Fashion         92        105        82        96
# C005  정수빈  28   구로      Fashion         82         88        94        79
# C006  윤태영  27   시흥  Electronics         88         95        85        91
# C007  한유진  31   파주          NaN         68         65        77        83
# C008  강민호  29   일산       Sports         98        125        96        90

# %% [markdown]
# ### 데이터 수정

# %% [markdown]
# **replace()**
# - 데이터 프레임이나 시리즈의 특정 값을 다른 값으로 바꿔주는 기능

# %%
df['거주도시'].replace('울산', '창원')
# Out:
# 고객ID
# C001    시흥
# C002    안양
# C003    창원
# C004    창원
# C005    구로
# C006    시흥
# C007    파주
# C008    일산
# Name: 거주도시, dtype: object

# %%
df['거주도시'].replace({'울산' : '창원'},{'시흥' : '부천'})

df
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_17516\1245188834.py in ?()
# ----> 1 df['거주도시'].replace({'울산' : '창원'},{'시흥' : '부천'})
#       2
#       3 df
#
# c:\ProgramData\miniforge3\envs\helloworld\Lib\site-packages\pandas\core\generic.py in ?(self, to_replace, value, inplace, limit, regex, method)
#    8092                         col: (to_replace[col], value[col])
#    8093                         for col in to_replace.keys()
#    8094                         if col in value.keys() and col in self
#    8095                     }
# -> 8096                     return self._replace_columnwise(mapping, inplace, regex)
#    8097
#    8098                 # {'A': NA} -> 0
#    8099                 elif not is_list_like(value):
#
# c:\ProgramData\miniforge3\envs\helloworld\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6317             and name not in self._accessors
#    6318             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6319         ):
#    6320             return self[name]
# -> 6321         return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute '_replace_columnwise'

# %%
df['거주도시'] = df['거주도시'] + '시'

# %%
df['주요관심사'] = df['주요관심사'].str.upper()

df
# Out:
#       고객명  나이    거주도시        주요관심사  최근1년_방문빈도  평균구매액(만원)  고객만족도(점)  재구매의사(점)
# 고객ID
# C001  박태근  35  시흥시시시시  ELECTRONICS         75         70        78        92
# C002  이영희  30  안양시시시시      FASHION         85         92        88        85
# C003  박지성  35  울산시시시시          NaN         95        110        91        88
# C004  최민아  40  창원시시시시      FASHION         92        105        82        96
# C005  정수빈  28  구로시시시시      FASHION         82         88        94        79
# C006  윤태영  27  시흥시시시시  ELECTRONICS         88         95        85        91
# C007  한유진  31  파주시시시시          NaN         68         65        77        83
# C008  강민호  29  일산시시시시       SPORTS         98        125        96        90

# %% [markdown]
# 거주도시를 ~~시까지 붙이고싶다면?

# %% [markdown]
# 고객만족도와 재구매의사 점수의 총점을 보고싶다면?

# %%
df['총합'] = df['고객만족도(점)'] + df['재구매의사(점)']

df
# Out:
#       고객명  나이    거주도시        주요관심사  최근1년_방문빈도  평균구매액(만원)  고객만족도(점)  재구매의사(점)  \
# 고객ID
# C001  박태근  35  시흥시시시시  ELECTRONICS         75         70        78        92
# C002  이영희  30  안양시시시시      FASHION         85         92        88        85
# C003  박지성  35  울산시시시시          NaN         95        110        91        88
# C004  최민아  40  창원시시시시      FASHION         92        105        82        96
# C005  정수빈  28  구로시시시시      FASHION         82         88        94        79
# C006  윤태영  27  시흥시시시시  ELECTRONICS         88         95        85        91
# C007  한유진  31  파주시시시시          NaN         68         65        77        83
# C008  강민호  29  일산시시시시       SPORTS         98        125        96        90
#
#        종합   총합
# 고객ID
# C001  170  170
# C002  173  173
# C003  179  179
# C004  178  178
# C005  173  173
# C006  176  176
# C007  160  160
# C008  186  186

# %%
filter = df['총합'] >= 175

# %%
df.loc[filter, '결과'] = 'GOOD'
df.loc[~filter, '결과'] = 'BAD'

# %%
df
# Out:
#       고객명  나이    거주도시        주요관심사  최근1년_방문빈도  평균구매액(만원)  고객만족도(점)  재구매의사(점)  \
# 고객ID
# C001  박태근  35  시흥시시시시  ELECTRONICS         75         70        78        92
# C002  이영희  30  안양시시시시      FASHION         85         92        88        85
# C003  박지성  35  울산시시시시          NaN         95        110        91        88
# C004  최민아  40  창원시시시시      FASHION         92        105        82        96
# C005  정수빈  28  구로시시시시      FASHION         82         88        94        79
# C006  윤태영  27  시흥시시시시  ELECTRONICS         88         95        85        91
# C007  한유진  31  파주시시시시          NaN         68         65        77        83
# C008  강민호  29  일산시시시시       SPORTS         98        125        96        90
#
#        종합   총합    결과
# 고객ID
# C001  170  170   BAD
# C002  173  173   BAD
# C003  179  179  GOOD
# C004  178  178  GOOD
# C005  173  173   BAD
# C006  176  176  GOOD
# C007  160  160   BAD
# C008  186  186  GOOD

# %% [markdown]
# Column 삭제

# %%
df.drop(columns = ['총합'], inplace=True)

df
# Out:
#       고객명  나이    거주도시        주요관심사  최근1년_방문빈도  평균구매액(만원)  고객만족도(점)  재구매의사(점)  \
# 고객ID
# C001  박태근  35  시흥시시시시  ELECTRONICS         75         70        78        92
# C002  이영희  30  안양시시시시      FASHION         85         92        88        85
# C003  박지성  35  울산시시시시          NaN         95        110        91        88
# C004  최민아  40  창원시시시시      FASHION         92        105        82        96
# C005  정수빈  28  구로시시시시      FASHION         82         88        94        79
# C006  윤태영  27  시흥시시시시  ELECTRONICS         88         95        85        91
# C007  한유진  31  파주시시시시          NaN         68         65        77        83
# C008  강민호  29  일산시시시시       SPORTS         98        125        96        90
#
#        종합    결과
# 고객ID
# C001  170   BAD
# C002  173   BAD
# C003  179  GOOD
# C004  178  GOOD
# C005  173   BAD
# C006  176  GOOD
# C007  160   BAD
# C008  186  GOOD

# %% [markdown]
# Row 삭제

# %%
df.drop(index = ['C003', 'C005'])
# Out:
#       고객명  나이    거주도시        주요관심사  최근1년_방문빈도  평균구매액(만원)  고객만족도(점)  재구매의사(점)  \
# 고객ID
# C001  박태근  35  시흥시시시시  ELECTRONICS         75         70        78        92
# C002  이영희  30  안양시시시시      FASHION         85         92        88        85
# C004  최민아  40  창원시시시시      FASHION         92        105        82        96
# C006  윤태영  27  시흥시시시시  ELECTRONICS         88         95        85        91
# C007  한유진  31  파주시시시시          NaN         68         65        77        83
# C008  강민호  29  일산시시시시       SPORTS         98        125        96        90
#
#        종합    결과
# 고객ID
# C001  170   BAD
# C002  173   BAD
# C004  178  GOOD
# C006  176  GOOD
# C007  160   BAD
# C008  186  GOOD

# %% [markdown]
# 박지성의 주요관심사를 SPORTS로 변경해보자

# %%
df.loc['C003', '주요관심사'] = 'SPOARTS'

df
# Out:
#       고객명  나이    거주도시        주요관심사  최근1년_방문빈도  평균구매액(만원)  고객만족도(점)  재구매의사(점)  \
# 고객ID
# C001  박태근  35  시흥시시시시  ELECTRONICS         75         70        78        92
# C002  이영희  30  안양시시시시      FASHION         85         92        88        85
# C003  박지성  35  울산시시시시      SPOARTS         95        110        91        88
# C004  최민아  40  창원시시시시      FASHION         92        105        82        96
# C005  정수빈  28  구로시시시시      FASHION         82         88        94        79
# C006  윤태영  27  시흥시시시시  ELECTRONICS         88         95        85        91
# C007  한유진  31  파주시시시시          NaN         68         65        77        83
# C008  강민호  29  일산시시시시       SPORTS         98        125        96        90
#
#        종합    결과
# 고객ID
# C001  170   BAD
# C002  173   BAD
# C003  179  GOOD
# C004  178  GOOD
# C005  173   BAD
# C006  176  GOOD
# C007  160   BAD
# C008  186  GOOD

# %% [markdown]
# 한유진의 거주도시를 부천시로, 주요관심사를 FASHION으로 수정해보자

# %%
df.loc['C007', ['주요관심사', '거주도시']] = ['FASION', '부천시시시시']

df
# Out:
#       고객명  나이    거주도시        주요관심사  최근1년_방문빈도  평균구매액(만원)  고객만족도(점)  재구매의사(점)  \
# 고객ID
# C001  박태근  35  시흥시시시시  ELECTRONICS         75         70        78        92
# C002  이영희  30  안양시시시시      FASHION         85         92        88        85
# C003  박지성  35  울산시시시시      SPOARTS         95        110        91        88
# C004  최민아  40  창원시시시시      FASHION         92        105        82        96
# C005  정수빈  28  구로시시시시      FASHION         82         88        94        79
# C006  윤태영  27  시흥시시시시  ELECTRONICS         88         95        85        91
# C007  한유진  31  부천시시시시       FASION         68         65        77        83
# C008  강민호  29  일산시시시시       SPORTS         98        125        96        90
#
#        종합    결과
# 고객ID
# C001  170   BAD
# C002  173   BAD
# C003  179  GOOD
# C004  178  GOOD
# C005  173   BAD
# C006  176  GOOD
# C007  160   BAD
# C008  186  GOOD
