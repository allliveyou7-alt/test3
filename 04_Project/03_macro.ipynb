# %%
# %pip install pyautogui
# Out:
# ...
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Preparing metadata (setup.py): started
# ...

# %%
import pyautogui

# (100, 200) 위치로 마우스 이동
pyautogui.moveTo(100, 200)

# 마우스 왼쪽 버튼 클릭
pyautogui.click()

# "Hello, world!" 입력
pyautogui.write('Hello, world!')

# 엔터키 입력
pyautogui.press('enter')

# Ctrl+C 누르기 (복사 동작 등)
pyautogui.hotkey('ctrl', 'c')

# 스크린샷 이미지를 찾아 클릭하기
button_location = pyautogui.locateOnScreen('button.png')
if button_location:
    pyautogui.click(button_location)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 19
#      16 pyautogui.hotkey('ctrl', 'c')
#      18 # 스크린샷 이미지를 찾아 클릭하기
# ---> 19 button_location = pyautogui.locateOnScreen('button.png')
#      20 if button_location:
#      21     pyautogui.click(button_location)
#
# File c:\ProgramData\miniforge3\envs\helloworld\Lib\site-packages\pyautogui\__init__.py:172, in raisePyAutoGUIImageNotFoundException.<locals>.wrapper(*args, **kwargs)
#     169 @functools.wraps(wrappedFunction)
#     170 def wrapper(*args, **kwargs):
#     171     try:
# --> 172         return wrappedFunction(*args, **kwargs)
#     173     except pyscreeze.ImageNotFoundException:
#     174         raise ImageNotFoundException
#
# File c:\ProgramData\miniforge3\envs\helloworld\Lib\site-packages\pyautogui\__init__.py:210, in locateOnScreen(*args, **kwargs)
# ...

# %%
import pyautogui
import time

try:
    while True:
        x, y = pyautogui.position()  # 마우스의 현재 좌표 얻기
        print(f"현재 마우스 위치: x={x}, y={y}")
        time.sleep(0.1)  # 0.1초 대기 (초당 10번 출력)
except KeyboardInterrupt:
    print("프로그램을 종료합니다.")
# Out:
# 현재 마우스 위치: x=643, y=573
# 현재 마우스 위치: x=643, y=573
# 현재 마우스 위치: x=643, y=573
# 현재 마우스 위치: x=643, y=573
# 현재 마우스 위치: x=643, y=573
# 현재 마우스 위치: x=643, y=573
# 현재 마우스 위치: x=643, y=573
# 현재 마우스 위치: x=643, y=573
# 현재 마우스 위치: x=643, y=573
# 현재 마우스 위치: x=643, y=573
# 현재 마우스 위치: x=676, y=580
# 현재 마우스 위치: x=746, y=674
# 현재 마우스 위치: x=807, y=703
# 현재 마우스 위치: x=880, y=761
# 현재 마우스 위치: x=1004, y=811
# 현재 마우스 위치: x=1025, y=830
# 현재 마우스 위치: x=1028, y=850
# 현재 마우스 위치: x=924, y=859
# 현재 마우스 위치: x=865, y=845
# 현재 마우스 위치: x=861, y=839
# 현재 마우스 위치: x=861, y=840
# 현재 마우스 위치: x=859, y=839
# 현재 마우스 위치: x=862, y=829
# 현재 마우스 위치: x=879, y=817
# 현재 마우스 위치: x=970, y=816
# 현재 마우스 위치: x=1072, y=817
# 현재 마우스 위치: x=1070, y=821
# 현재 마우스 위치: x=1065, y=825
# 현재 마우스 위치: x=1063, y=824
# 현재 마우스 위치: x=1058, y=818
# 현재 마우스 위치: x=998, y=798
# 현재 마우스 위치: x=986, y=797
# 현재 마우스 위치: x=982, y=796
# 현재 마우스 위치: x=952, y=793
# 현재 마우스 위치: x=901, y=794
# 현재 마우스 위치: x=819, y=795
# 현재 마우스 위치: x=722, y=787
# 현재 마우스 위치: x=721, y=787
# ...

# %%
import pyautogui
import time

# 각 요소의 클릭 좌표를 미리 설정합니다. (실제 환경에 맞게 수정 필요)
pos_start_year = (935, 679)     # 시작년도 클릭 좌표
pos_start_month = (1065, 679)    # 시작월 클릭 좌표
pos_end_year = (1218, 679)       # 끝년도 클릭 좌표
pos_end_month = (1357, 679)      # 끝월 클릭 좌표
pos_search_btn = (1411, 916)     # 검색버튼 클릭 좌표
pos_download_btn = (1462, 975)   # 엑셀 파일 다운로드 좌표

# 1. 시작년도 클릭 - 입력 - 엔터
pyautogui.click(pos_start_year)
time.sleep(0.2)
pyautogui.typewrite('2025')      # 년도 입력
time.sleep(0.2)
pyautogui.press('enter')

# 2. 시작월 클릭 - 입력 - 엔터
pyautogui.click(pos_start_month)
time.sleep(0.2)
pyautogui.typewrite('01')        # 월 입력
time.sleep(0.2)
pyautogui.press('enter')

# 3. 끝년도 클릭 - 입력 - 엔터
pyautogui.click(pos_end_year)
time.sleep(0.2)
pyautogui.typewrite('2025')      # 년도 입력
time.sleep(0.2)
pyautogui.press('enter')

# 4. 끝월 클릭 - 입력 - 엔터
pyautogui.click(pos_end_month)
time.sleep(0.2)
pyautogui.typewrite('06')        # 월 입력
time.sleep(0.2)
pyautogui.press('enter')

# 5. 검색버튼 클릭 - 5초 이상 대기
pyautogui.click(pos_search_btn)
time.sleep(5.5)

# 6. 엑셀파일 다운로드 클릭 - 1초 대기 후 엔터
pyautogui.click(pos_download_btn)
time.sleep(1)
pyautogui.press('enter')
